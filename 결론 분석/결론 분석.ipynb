# %%
import pandas as pd
import numpy as np
import sqlite3
from sklearn.preprocessing import MinMaxScaler
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
from urllib.request import urlopen
from selenium.webdriver.common.keys import Keys
import time

# %%
scaler = MinMaxScaler()

# %%
# 자치구별 임대료 / 면적 데이터
seoul_district = pd.read_csv("C:/Users/ITSC/Desktop/MiniPrj2/Git/Data/seoul_district.csv")

# %%
# 자치구별 유동인구 종합 데이터
float_pop_data = pd.read_csv("C:/Users/ITSC/Desktop/MiniPrj2/Git/Data/유동인구종합.csv")

# %%
# 자치구별 건물연식 종합 데이터
district_age_data = pd.read_csv("C:/Users/ITSC/Desktop/MiniPrj2/Git/Data/district_age_data.csv")

# %%
# 자치구별 연령대 인구 데이터
seoul_pop_data = pd.read_csv("C:/Users/ITSC/Desktop/MiniPrj2/Git/Data/seoul_pop.csv")

# %%
# 자치구별 소득 데이터
seoul_income_data = pd.read_csv("C:/Users/ITSC/Desktop/MiniPrj2/Git/Data/seoul_income.csv")

# %%
# 자치구별 종사자, 사업체 수 데이터
employee_data = pd.read_csv("C:/Users/ITSC/Desktop/MiniPrj2/Git/Data/employee_data.csv")

# %%
# 자치구별 스타벅스 매장 수 데이터
starbucks_data = pd.read_csv("C:/Users/ITSC/Desktop/MiniPrj2/Git/Data/starbucks_data.csv")

# %% [markdown]
# ## 임대료 데이터 요약 전처리

# %%
seoul_district = seoul_district.iloc[:, [0, 1, 3, 10, 12]]

# %%
seoul_district = seoul_district.rename(columns = {"Unnamed: 0" : "index"})

# %%
seoul_district = seoul_district.iloc[:, 1:].reset_index()

# %%
seoul_district
# Out:
#     index   자치구  중대형 1층  소형 1층  면적 (km²)
# 0       0   강남구   64.54  64.67     39.50
# 1       1   강동구   47.20  56.10     24.59
# 2       2   강북구   45.93  42.60     23.60
# 3       3   강서구   35.20  28.70     41.45
# 4       4   관악구   72.80  65.75     29.57
# 5       5   광진구   52.55  39.40     17.06
# 6       6   구로구   45.20  47.10     20.12
# 7       7   금천구   33.20  31.20     13.02
# 8       8   노원구   29.60  26.00     35.44
# 9       9  동대문구   44.32  42.40     14.22
# 10     10   동작구   53.75  35.35     16.36
# 11     11   마포구   45.32  50.92     23.85
# 12     12  서대문구   63.20  45.40     17.63
# 13     13   서초구   33.20  40.00     46.97
# 14     14   성동구   44.55  48.00     16.82
# 15     15   송파구   39.97  32.50     33.88
# 16     16   양천구   33.80  35.10     17.41
# 17     17  영등포구   34.60  35.60     24.55
# 18     18   용산구   40.60  45.90     21.87
# 19     19   은평구   46.10  40.60     29.71
# 20     20   종로구   73.67  67.53     23.91
# 21     21    중구   86.38  80.60      9.96
# 22     22   중랑구   38.00  46.50     18.50

# %%
seoul_district2 = pd.DataFrame(scaler.fit_transform(seoul_district.iloc[:, [2, 3]]))

# %%
seoul_district2 = seoul_district2.rename(columns = {0 : "중대형 정규화", 1 : "소형 정규화"})

# %%
seoul_district2["자치구"] = seoul_district["자치구"]

# %%
seoul_district2 = seoul_district2.iloc[:, [2, 0, 1]]

# %%
seoul_district2
# Out:
#      자치구   중대형 정규화    소형 정규화
# 0    강남구  0.615358  0.708242
# 1    강동구  0.309968  0.551282
# 2    강북구  0.287601  0.304029
# 3    강서구  0.098626  0.049451
# 4    관악구  0.760831  0.728022
# 5    광진구  0.404192  0.245421
# 6    구로구  0.274745  0.386447
# 7    금천구  0.063403  0.095238
# 8    노원구  0.000000  0.000000
# 9   동대문구  0.259246  0.300366
# 10   동작구  0.425326  0.171245
# 11   마포구  0.276858  0.456410
# 12  서대문구  0.591758  0.355311
# 13   서초구  0.063403  0.256410
# 14   성동구  0.263297  0.402930
# 15   송파구  0.182635  0.119048
# 16   양천구  0.073970  0.166667
# 17  영등포구  0.088059  0.175824
# 18   용산구  0.193730  0.364469
# 19   은평구  0.290595  0.267399
# 20   종로구  0.776154  0.760623
# 21    중구  1.000000  1.000000
# 22   중랑구  0.147939  0.375458

# %% [markdown]
# ## 유동인구를 근거로 상권 임대료 평가

# %%
float_pop_data2 = float_pop_data.iloc[:, 12].reset_index()

# %%
float_pop_data2 = pd.merge(seoul_district, float_pop_data2, on = "index", how = "inner")

# %%
float_pop_data2.drop(21)
# Out:
#     index   자치구  중대형 1층  소형 1층  면적 (km²)      종합/면적
# 0       0   강남구   64.54  64.67     39.50  1265358.0
# 1       1   강동구   47.20  56.10     24.59   524493.0
# 2       2   강북구   45.93  42.60     23.60   643757.0
# 3       3   강서구   35.20  28.70     41.45   515846.0
# 4       4   관악구   72.80  65.75     29.57   794169.0
# 5       5   광진구   52.55  39.40     17.06   991992.0
# 6       6   구로구   45.20  47.10     20.12  1089458.0
# 7       7   금천구   33.20  31.20     13.02   956760.0
# 8       8   노원구   29.60  26.00     35.44   545175.0
# 9       9  동대문구   44.32  42.40     14.22  1238371.0
# 10     10   동작구   53.75  35.35     16.36  1385262.0
# 11     11   마포구   45.32  50.92     23.85  1219940.0
# 12     12  서대문구   63.20  45.40     17.63  1006588.0
# 13     13   서초구   33.20  40.00     46.97   712862.0
# 14     14   성동구   44.55  48.00     16.82  1089352.0
# 15     15   송파구   39.97  32.50     33.88   969803.0
# 16     16   양천구   33.80  35.10     17.41   827074.0
# 17     17  영등포구   34.60  35.60     24.55  1292575.0
# 18     18   용산구   40.60  45.90     21.87  1039013.0
# 19     19   은평구   46.10  40.60     29.71   626412.0
# 20     20   종로구   73.67  67.53     23.91  1151200.0
# 22     22   중랑구   38.00  46.50     18.50   661976.0

# %%
float_pop_data3 = pd.concat([float_pop_data2.drop(21).reset_index(drop = True), pd.DataFrame(scaler.fit_transform(float_pop_data2.drop(21).iloc[:, 2:]))], axis = 1)

# %%
float_pop_data3 = float_pop_data3.rename(columns = {0 : "중대형 정규화", 1 : "소형 정규화", 3 : "유동 정규화"}).iloc[:, [1, 2, 3, 4, 5, 6, 7, 9]]

# %%
float_pop_data3["중대형 평가"] = float_pop_data3["유동 정규화"] - float_pop_data3["중대형 정규화"]
float_pop_data3["소형 평가"] = float_pop_data3["유동 정규화"] - float_pop_data3["소형 정규화"]

# %%
float_pop_data3.sort_values(by = "중대형 평가", ascending = False).reset_index(drop = True)
# Out:
#      자치구  중대형 1층  소형 1층  면적 (km²)      종합/면적   중대형 정규화    소형 정규화    유동 정규화  \
# 0   영등포구   34.60  35.60     24.55  1292575.0  0.113456  0.231158  0.893392
# 1   동대문구   44.32  42.40     14.22  1238371.0  0.334014  0.394895  0.831046
# 2    마포구   45.32  50.92     23.85  1219940.0  0.356705  0.600048  0.809847
# 3    동작구   53.75  35.35     16.36  1385262.0  0.547992  0.225138  1.000000
# 4    금천구   33.20  31.20     13.02   956760.0  0.081688  0.125211  0.507138
# 5    용산구   40.60  45.90     21.87  1039013.0  0.249603  0.479172  0.601745
# 6    성동구   44.55  48.00     16.82  1089352.0  0.339233  0.529738  0.659645
# 7    구로구   45.20  47.10     20.12  1089458.0  0.353982  0.508066  0.659767
# 8    송파구   39.97  32.50     33.88   969803.0  0.235307  0.156513  0.522140
# 9    양천구   33.80  35.10     17.41   827074.0  0.095303  0.219119  0.357974
# 10   서초구   33.20  40.00     46.97   712862.0  0.081688  0.337106  0.226607
# 11   강남구   64.54  64.67     39.50  1265358.0  0.792830  0.931134  0.862087
# 12   노원구   29.60  26.00     35.44   545175.0  0.000000  0.000000  0.033734
# 13   광진구   52.55  39.40     17.06   991992.0  0.520762  0.322658  0.547662
# 14   중랑구   38.00  46.50     18.50   661976.0  0.190606  0.493619  0.168078
# 15   강서구   35.20  28.70     41.45   515846.0  0.127071  0.065013  0.000000
# 16  서대문구   63.20  45.40     17.63  1006588.0  0.762423  0.467132  0.564450
# 17   강북구   45.93  42.60     23.60   643757.0  0.370547  0.399711  0.147123
# 18   은평구   46.10  40.60     29.71   626412.0  0.374404  0.351553  0.127173
# 19   종로구   73.67  67.53     23.91  1151200.0  1.000000  1.000000  0.730783
# 20   강동구   47.20  56.10     24.59   524493.0  0.399365  0.724777  0.009946
# 21   관악구   72.80  65.75     29.57   794169.0  0.980259  0.957139  0.320126
#
#       중대형 평가     소형 평가
# 0   0.779936  0.662233
# 1   0.497032  0.436151
# 2   0.453142  0.209799
# 3   0.452008  0.774862
# 4   0.425450  0.381927
# 5   0.352142  0.122574
# 6   0.320412  0.129908
# 7   0.305785  0.151701
# 8   0.286833  0.365627
# 9   0.262671  0.138855
# 10  0.144919 -0.110498
# 11  0.069257 -0.069047
# 12  0.033734  0.033734
# 13  0.026899  0.225004
# 14 -0.022528 -0.325541
# 15 -0.127071 -0.065013
# 16 -0.197973  0.097318
# 17 -0.223424 -0.252588
# 18 -0.247232 -0.224380
# 19 -0.269217 -0.269217
# 20 -0.389419 -0.714832
# 21 -0.660132 -0.637013

# %%
float_pop_data4 = float_pop_data3.sort_values(by = "중대형 평가", ascending = False).reset_index(drop = True)

# %%
float_pop_data4 = float_pop_data4.iloc[:, [0, -2, -1]]

# %%
float_pop_data3.sort_values(by = "중대형 평가", ascending = False).reset_index(drop = True).iloc[:, [0, 4, 5, 6, 7, 8, 9]]
# Out:
#      자치구      종합/면적   중대형 정규화    소형 정규화    유동 정규화    중대형 평가     소형 평가
# 0   영등포구  1292575.0  0.113456  0.231158  0.893392  0.779936  0.662233
# 1   동대문구  1238371.0  0.334014  0.394895  0.831046  0.497032  0.436151
# 2    마포구  1219940.0  0.356705  0.600048  0.809847  0.453142  0.209799
# 3    동작구  1385262.0  0.547992  0.225138  1.000000  0.452008  0.774862
# 4    금천구   956760.0  0.081688  0.125211  0.507138  0.425450  0.381927
# 5    용산구  1039013.0  0.249603  0.479172  0.601745  0.352142  0.122574
# 6    성동구  1089352.0  0.339233  0.529738  0.659645  0.320412  0.129908
# 7    구로구  1089458.0  0.353982  0.508066  0.659767  0.305785  0.151701
# 8    송파구   969803.0  0.235307  0.156513  0.522140  0.286833  0.365627
# 9    양천구   827074.0  0.095303  0.219119  0.357974  0.262671  0.138855
# 10   서초구   712862.0  0.081688  0.337106  0.226607  0.144919 -0.110498
# 11   강남구  1265358.0  0.792830  0.931134  0.862087  0.069257 -0.069047
# 12   노원구   545175.0  0.000000  0.000000  0.033734  0.033734  0.033734
# 13   광진구   991992.0  0.520762  0.322658  0.547662  0.026899  0.225004
# 14   중랑구   661976.0  0.190606  0.493619  0.168078 -0.022528 -0.325541
# 15   강서구   515846.0  0.127071  0.065013  0.000000 -0.127071 -0.065013
# 16  서대문구  1006588.0  0.762423  0.467132  0.564450 -0.197973  0.097318
# 17   강북구   643757.0  0.370547  0.399711  0.147123 -0.223424 -0.252588
# 18   은평구   626412.0  0.374404  0.351553  0.127173 -0.247232 -0.224380
# 19   종로구  1151200.0  1.000000  1.000000  0.730783 -0.269217 -0.269217
# 20   강동구   524493.0  0.399365  0.724777  0.009946 -0.389419 -0.714832
# 21   관악구   794169.0  0.980259  0.957139  0.320126 -0.660132 -0.637013

# %% [markdown]
# ## 자치구 건물 연식을 근거로 상권 임대료 평가

# %%
district_age_data2 = district_age_data.iloc[:, [0, 2]].rename(columns = {"Unnamed: 0" : "index"})

# %%
district_age_data2 = pd.merge(seoul_district, district_age_data2, on = "index", how = "inner")

# %%
district_age_data2 = district_age_data2.iloc[:, [0, 2, 3, 5]]

# %%
district_age_data2
# Out:
#     index  중대형 1층  소형 1층     연식
# 0       0   64.54  64.67  25.41
# 1       1   47.20  56.10  23.02
# 2       2   45.93  42.60  19.93
# 3       3   35.20  28.70  11.73
# 4       4   72.80  65.75  22.33
# 5       5   52.55  39.40  25.18
# 6       6   45.20  47.10  25.36
# 7       7   33.20  31.20  15.67
# 8       8   29.60  26.00  26.98
# 9       9   44.32  42.40  30.31
# 10     10   53.75  35.35  23.79
# 11     11   45.32  50.92  23.47
# 12     12   63.20  45.40  23.15
# 13     13   33.20  40.00  27.33
# 14     14   44.55  48.00  22.62
# 15     15   39.97  32.50  22.42
# 16     16   33.80  35.10  23.75
# 17     17   34.60  35.60  28.55
# 18     18   40.60  45.90  29.97
# 19     19   46.10  40.60  16.37
# 20     20   73.67  67.53  25.03
# 21     21   86.38  80.60  33.14
# 22     22   38.00  46.50  14.01

# %%
seoul_district.iloc[:, :2]
# Out:
#     index   자치구
# 0       0   강남구
# 1       1   강동구
# 2       2   강북구
# 3       3   강서구
# 4       4   관악구
# 5       5   광진구
# 6       6   구로구
# 7       7   금천구
# 8       8   노원구
# 9       9  동대문구
# 10     10   동작구
# 11     11   마포구
# 12     12  서대문구
# 13     13   서초구
# 14     14   성동구
# 15     15   송파구
# 16     16   양천구
# 17     17  영등포구
# 18     18   용산구
# 19     19   은평구
# 20     20   종로구
# 21     21    중구
# 22     22   중랑구

# %%
district_age_data3 = pd.concat([seoul_district.iloc[:, :2], pd.DataFrame(scaler.fit_transform(district_age_data2.iloc[:, 1:])).rename(columns = {0 : "중대형 정규화", 1 : "소형 정규화", 2 : "연식 정규화"})], axis = 1)

# %%
district_age_data3["중대형 평가"] = round(district_age_data3["연식 정규화"] - district_age_data3["중대형 정규화"], 4)
district_age_data3["소형 평가"] = round(district_age_data3["연식 정규화"] - district_age_data3["소형 정규화"], 4)

# %%
district_age_data3.sort_values(by = "중대형 평가", ascending = False).reset_index(drop = True)
# Out:
#     index   자치구   중대형 정규화    소형 정규화    연식 정규화  중대형 평가   소형 평가
# 0       8   노원구  0.000000  0.000000  0.712284  0.7123  0.7123
# 1      17  영등포구  0.088059  0.175824  0.785614  0.6976  0.6098
# 2      13   서초구  0.063403  0.256410  0.728631  0.6652  0.4722
# 3      18   용산구  0.193730  0.364469  0.851938  0.6582  0.4875
# 4       9  동대문구  0.259246  0.300366  0.867819  0.6086  0.5675
# 5      16   양천구  0.073970  0.166667  0.561420  0.4875  0.3948
# 6       6   구로구  0.274745  0.386447  0.636618  0.3619  0.2502
# 7      15   송파구  0.182635  0.119048  0.499299  0.3167  0.3803
# 8      11   마포구  0.276858  0.456410  0.548342  0.2715  0.0919
# 9      14   성동구  0.263297  0.402930  0.508641  0.2453  0.1057
# 10      5   광진구  0.404192  0.245421  0.628211  0.2240  0.3828
# 11      1   강동구  0.309968  0.551282  0.527324  0.2174 -0.0240
# 12     10   동작구  0.425326  0.171245  0.563288  0.1380  0.3920
# 13      7   금천구  0.063403  0.095238  0.184026  0.1206  0.0888
# 14      2   강북구  0.287601  0.304029  0.382999  0.0954  0.0790
# 15      0   강남구  0.615358  0.708242  0.638954  0.0236 -0.0693
# 16     21    중구  1.000000  1.000000  1.000000 -0.0000  0.0000
# 17     22   중랑구  0.147939  0.375458  0.106492 -0.0414 -0.2690
# 18     12  서대문구  0.591758  0.355311  0.533396 -0.0584  0.1781
# 19     19   은평구  0.290595  0.267399  0.216721 -0.0739 -0.0507
# 20      3   강서구  0.098626  0.049451  0.000000 -0.0986 -0.0495
# 21     20   종로구  0.776154  0.760623  0.621205 -0.1549 -0.1394
# 22      4   관악구  0.760831  0.728022  0.495096 -0.2657 -0.2329

# %% [markdown]
# ## 자치구의 연령별 인구 비율을 근거로 임대료 평가

# %%
seoul_pop_data2 = seoul_pop_data.iloc[:, -7:-4]

# %%
seoul_pop_scaled = pd.DataFrame(scaler.fit_transform(seoul_pop_data2))

# %%
seoul_pop_scaled = seoul_pop_scaled.rename(columns = {0 : "30대", 1 : "40대", 2 : "50대"})

# %%
seoul_pop_data3 = pd.concat([seoul_district2, seoul_pop_scaled], axis = 1)

# %%
seoul_pop_data3["중대형 평가"] = seoul_pop_data3["중대형 정규화"] - 1 + seoul_pop_data3["50대"]
seoul_pop_data3["소형 평가"] = seoul_pop_data3["소형 정규화"] - 1 + seoul_pop_data3["50대"]

# %%
seoul_pop_data3.sort_values(by = "소형 평가").reset_index(drop = True)
# Out:
#      자치구   중대형 정규화    소형 정규화       30대       40대       50대    중대형 평가     소형 평가
# 0    강서구  0.098626  0.049451  0.517826  0.375531  0.301230 -0.600144 -0.649319
# 1    서초구  0.063403  0.256410  0.125609  0.211361  0.109979 -0.826619 -0.633611
# 2    노원구  0.000000  0.000000  0.302293  0.385209  0.427930 -0.572070 -0.572070
# 3    용산구  0.193730  0.364469  0.344997  0.211831  0.185940 -0.620330 -0.449591
# 4   영등포구  0.088059  0.175824  0.751367  0.452731  0.453112 -0.458829 -0.371064
# 5    강북구  0.287601  0.304029  0.223580  0.256902  0.337491 -0.374907 -0.358479
# 6    송파구  0.182635  0.119048  0.784161  0.693216  0.599630 -0.217735 -0.281322
# 7    금천구  0.063403  0.095238  0.772134  0.479652  0.657622 -0.278976 -0.247140
# 8    은평구  0.290595  0.267399  0.483080  0.459123  0.486181 -0.223224 -0.246420
# 9    종로구  0.776154  0.760623  0.000000  0.000000  0.000000 -0.223846 -0.239377
# 10   마포구  0.276858  0.456410  0.658221  0.473806  0.408239 -0.314903 -0.135350
# 11  서대문구  0.591758  0.355311  0.620468  0.514602  0.540113  0.131870 -0.104576
# 12   성동구  0.263297  0.402930  0.662484  0.484723  0.501171 -0.235532 -0.095898
# 13   광진구  0.404192  0.245421  0.861487  0.611137  0.661300  0.065491 -0.093279
# 14   동작구  0.425326  0.171245  1.000000  0.760806  0.772790  0.198116 -0.055964
# 15   강남구  0.615358  0.708242  0.401622  0.500587  0.347980 -0.036662  0.056222
# 16   구로구  0.274745  0.386447  0.818932  0.675557  0.723966 -0.001290  0.110413
# 17   관악구  0.760831  0.728022  0.769118  0.386659  0.386578  0.147409  0.114600
# 18   강동구  0.309968  0.551282  0.677676  0.657403  0.567760 -0.122272  0.119042
# 19  동대문구  0.259246  0.300366  0.959927  0.788694  0.825687  0.084933  0.126053
# 20   중랑구  0.147939  0.375458  0.803194  0.614919  0.758823 -0.093238  0.134281
# 21   양천구  0.073970  0.166667  0.768039  1.000000  1.000000  0.073970  0.166667
# 22    중구  1.000000  1.000000  0.491516  0.289248  0.304077  0.304077  0.304077

# %%
seoul_pop_data4 = seoul_pop_data3.sort_values(by = "소형 평가").reset_index(drop = True)

# %%
seoul_pop_data4 = seoul_pop_data4.iloc[:, [0, -2, -1]]

# %% [markdown]
# ## 자치구별 소득 수준에 따른 임대료 평가

# %%
seoul_income_data2 = seoul_income_data.iloc[:, 2:]

# %%
seoul_income_data2
# Out:
#     지역내총생산(당해년가격) (백만원)  1인당 지역내총생산 (천원)
# 0              77924019           155358
# 1               9364063            20717
# 2               3462961            11754
# 3              18347568            32709
# 4               6347562            12792
# 5               6554954            18732
# 6              14663398            34144
# 7              17801015            71770
# 8               6728358            13331
# 9               7711273            22164
# 10              6712864            17250
# 11             21399314            58606
# 12              9039083            28793
# 13             38335706            96783
# 14             13999893            48682
# 15             31834324            50290
# 16              7356067            16897
# 17             44265877           109100
# 18             13294640            58918
# 19              5112192            11139
# 20             35719537           238599
# 21             61342710           481395
# 22              4860242            12742

# %%
seoul_income_data3 = pd.DataFrame(scaler.fit_transform(seoul_income_data2)).rename(columns = {0 : "지역내 총생산(100만)", 1 : "1인당 지역내 총생산(1천)"})

# %%
seoul_income_data4 = pd.concat([seoul_district2, seoul_income_data3], axis = 1)

# %%
seoul_income_data4
# Out:
#      자치구   중대형 정규화    소형 정규화  지역내 총생산(100만)  1인당 지역내 총생산(1천)
# 0    강남구  0.615358  0.708242       1.000000         0.306682
# 1    강동구  0.309968  0.551282       0.079251         0.020368
# 2    강북구  0.287601  0.304029       0.000000         0.001308
# 3    강서구  0.098626  0.049451       0.199898         0.045869
# 4    관악구  0.760831  0.728022       0.038740         0.003515
# 5    광진구  0.404192  0.245421       0.041525         0.016147
# 6    구로구  0.274745  0.386447       0.150420         0.048920
# 7    금천구  0.063403  0.095238       0.192558         0.128932
# 8    노원구  0.000000  0.000000       0.043854         0.004661
# 9   동대문구  0.259246  0.300366       0.057054         0.023445
# 10   동작구  0.425326  0.171245       0.043646         0.012995
# 11   마포구  0.276858  0.456410       0.240882         0.100939
# 12  서대문구  0.591758  0.355311       0.074886         0.037541
# 13   서초구  0.063403  0.256410       0.468335         0.182122
# 14   성동구  0.263297  0.402930       0.141509         0.079835
# 15   송파구  0.182635  0.119048       0.381023         0.083255
# 16   양천구  0.073970  0.166667       0.052284         0.012244
# 17  영등포구  0.088059  0.175824       0.547977         0.208314
# 18   용산구  0.193730  0.364469       0.132038         0.101602
# 19   은평구  0.290595  0.267399       0.022149         0.000000
# 20   종로구  0.776154  0.760623       0.433201         0.483694
# 21    중구  1.000000  1.000000       0.777316         1.000000
# 22   중랑구  0.147939  0.375458       0.018765         0.003409

# %%
seoul_income_data4["중대형 평가"] = seoul_income_data4["1인당 지역내 총생산(1천)"] - seoul_income_data4["중대형 정규화"]
seoul_income_data4["소형 평가"] = seoul_income_data4["1인당 지역내 총생산(1천)"] - seoul_income_data4["중대형 정규화"]

# %%
seoul_income_data4.sort_values(by = "중대형 평가", ascending = False).reset_index(drop = True)
# Out:
#      자치구   중대형 정규화    소형 정규화  지역내 총생산(100만)  1인당 지역내 총생산(1천)    중대형 평가  \
# 0   영등포구  0.088059  0.175824       0.547977         0.208314  0.120255
# 1    서초구  0.063403  0.256410       0.468335         0.182122  0.118719
# 2    금천구  0.063403  0.095238       0.192558         0.128932  0.065529
# 3    노원구  0.000000  0.000000       0.043854         0.004661  0.004661
# 4     중구  1.000000  1.000000       0.777316         1.000000  0.000000
# 5    강서구  0.098626  0.049451       0.199898         0.045869 -0.052758
# 6    양천구  0.073970  0.166667       0.052284         0.012244 -0.061725
# 7    용산구  0.193730  0.364469       0.132038         0.101602 -0.092128
# 8    송파구  0.182635  0.119048       0.381023         0.083255 -0.099380
# 9    중랑구  0.147939  0.375458       0.018765         0.003409 -0.144531
# 10   마포구  0.276858  0.456410       0.240882         0.100939 -0.175919
# 11   성동구  0.263297  0.402930       0.141509         0.079835 -0.183462
# 12   구로구  0.274745  0.386447       0.150420         0.048920 -0.225824
# 13  동대문구  0.259246  0.300366       0.057054         0.023445 -0.235802
# 14   강북구  0.287601  0.304029       0.000000         0.001308 -0.286293
# 15   강동구  0.309968  0.551282       0.079251         0.020368 -0.289601
# 16   은평구  0.290595  0.267399       0.022149         0.000000 -0.290595
# 17   종로구  0.776154  0.760623       0.433201         0.483694 -0.292460
# 18   강남구  0.615358  0.708242       1.000000         0.306682 -0.308676
# 19   광진구  0.404192  0.245421       0.041525         0.016147 -0.388045
# 20   동작구  0.425326  0.171245       0.043646         0.012995 -0.412331
# 21  서대문구  0.591758  0.355311       0.074886         0.037541 -0.554216
# 22   관악구  0.760831  0.728022       0.038740         0.003515 -0.757316
#
#        소형 평가
# 0   0.120255
# 1   0.118719
# 2   0.065529
# 3   0.004661
# 4   0.000000
# 5  -0.052758
# 6  -0.061725
# 7  -0.092128
# 8  -0.099380
# 9  -0.144531
# 10 -0.175919
# 11 -0.183462
# 12 -0.225824
# 13 -0.235802
# 14 -0.286293
# 15 -0.289601
# 16 -0.290595
# 17 -0.292460
# 18 -0.308676
# 19 -0.388045
# 20 -0.412331
# 21 -0.554216
# 22 -0.757316

# %%
seoul_income_data5 = seoul_income_data4.sort_values(by = "중대형 평가", ascending = False).reset_index(drop = True)

# %%
seoul_income_data5 = seoul_income_data5.iloc[:, [0, -2, -1]]

# %% [markdown]
# ## 종사자수/자치구별 인구 기준으로 상가 임대료 평가

# %%
employee_data2 = employee_data.loc[employee_data["자치구"].isin(seoul_district["자치구"])].reset_index(drop = True).iloc[:, [5, 8]]

# %%
employee_data2
# Out:
#     종사자밀도(A)  종사자수/자치구별인구
# 0   11502.69       182.82
# 1   38810.63       293.31
# 2    6979.05        67.20
# 3   12053.51        71.36
# 4    7601.65        36.93
# 5   10297.20        40.68
# 6    6117.35        29.20
# 7    3399.17        27.38
# 8    3764.14        26.52
# 9    3669.78        23.16
# 10   6709.03        36.88
# 11  11731.11        74.58
# 12   7685.76        30.46
# 13   7007.42        51.07
# 14  11963.21        57.91
# 15  19619.01       105.95
# 16  17720.92       109.36
# 17   6681.80        28.04
# 18   4343.06        25.79
# 19  10386.53       118.42
# 20  20290.37       145.64
# 21  11830.46        60.72
# 22   6403.49        33.99

# %%
employee_data3 = pd.concat([seoul_district2, pd.DataFrame(scaler.fit_transform(employee_data2)).rename(columns = {0 : "종사자 밀도", 1 : "종사자수/인구"})], axis = 1)

# %%
employee_data3["중대형 평가"] = employee_data3["종사자수/인구"] - employee_data3["중대형 정규화"]
employee_data3["소형 평가"] = employee_data3["종사자수/인구"] - employee_data3["중대형 정규화"]

# %%
employee_data3.sort_values(by = "중대형 평가", ascending = False).reset_index(drop = True)
# Out:
#      자치구   중대형 정규화    소형 정규화    종사자 밀도   종사자수/인구    중대형 평가     소형 평가
# 0    강동구  0.309968  0.551282  1.000000  1.000000  0.690032  0.690032
# 1    양천구  0.073970  0.166667  0.404438  0.319082  0.245112  0.245112
# 2    송파구  0.182635  0.119048  0.458039  0.306459  0.123825  0.123825
# 3    강서구  0.098626  0.049451  0.244394  0.178419  0.079793  0.079793
# 4    은평구  0.290595  0.267399  0.197319  0.352619  0.062024  0.062024
# 5    서초구  0.063403  0.256410  0.101895  0.103313  0.039910  0.039910
# 6    노원구  0.000000  0.000000  0.010307  0.012438  0.012438  0.012438
# 7    강남구  0.615358  0.708242  0.228839  0.591005 -0.024353 -0.024353
# 8    금천구  0.063403  0.095238  0.000000  0.015621 -0.047782 -0.047782
# 9   영등포구  0.088059  0.175824  0.092700  0.018064 -0.069995 -0.069995
# 10   마포구  0.276858  0.456410  0.235289  0.190339 -0.086519 -0.086519
# 11   중랑구  0.147939  0.375458  0.084840  0.040089 -0.107851 -0.107851
# 12   강북구  0.287601  0.304029  0.101094  0.163021 -0.124581 -0.124581
# 13   성동구  0.263297  0.402930  0.241844  0.128632 -0.134665 -0.134665
# 14   용산구  0.193730  0.364469  0.026655  0.009735 -0.183995 -0.183995
# 15   구로구  0.274745  0.386447  0.076760  0.022358 -0.252387 -0.252387
# 16  동대문구  0.259246  0.300366  0.007642  0.000000 -0.259246 -0.259246
# 17   종로구  0.776154  0.760623  0.476998  0.453378 -0.322776 -0.322776
# 18   광진구  0.404192  0.245421  0.194797  0.064853 -0.339339 -0.339339
# 19   동작구  0.425326  0.171245  0.093469  0.050787 -0.374539 -0.374539
# 20  서대문구  0.591758  0.355311  0.121051  0.027022 -0.564736 -0.564736
# 21   관악구  0.760831  0.728022  0.118676  0.050972 -0.709860 -0.709860
# 22    중구  1.000000  1.000000  0.238095  0.139034 -0.860966 -0.860966

# %%
employee_data4 = employee_data3.sort_values(by = "중대형 평가", ascending = False).reset_index(drop = True)

# %%
employee_data4 = employee_data4.iloc[:, [0, -2, -1]]

# %% [markdown]
# ## 종합점수 매기기

# %%
float_pop_data4.iloc[:, :1].reset_index()
# Out:
#     index   자치구
# 0       0  영등포구
# 1       1  동대문구
# 2       2   마포구
# 3       3   동작구
# 4       4   금천구
# 5       5   용산구
# 6       6   성동구
# 7       7   구로구
# 8       8   송파구
# 9       9   양천구
# 10     10   서초구
# 11     11   강남구
# 12     12   노원구
# 13     13   광진구
# 14     14   중랑구
# 15     15   강서구
# 16     16  서대문구
# 17     17   강북구
# 18     18   은평구
# 19     19   종로구
# 20     20   강동구
# 21     21   관악구

# %%
seoul_pop_data4.iloc[:, :1].reset_index()
# Out:
#     index   자치구
# 0       0   강서구
# 1       1   서초구
# 2       2   노원구
# 3       3   용산구
# 4       4  영등포구
# 5       5   강북구
# 6       6   송파구
# 7       7   금천구
# 8       8   은평구
# 9       9   종로구
# 10     10   마포구
# 11     11  서대문구
# 12     12   성동구
# 13     13   광진구
# 14     14   동작구
# 15     15   강남구
# 16     16   구로구
# 17     17   관악구
# 18     18   강동구
# 19     19  동대문구
# 20     20   중랑구
# 21     21   양천구
# 22     22    중구

# %%
seoul_income_data5.iloc[:, :1].reset_index()
# Out:
#     index   자치구
# 0       0  영등포구
# 1       1   서초구
# 2       2   금천구
# 3       3   노원구
# 4       4    중구
# 5       5   강서구
# 6       6   양천구
# 7       7   용산구
# 8       8   송파구
# 9       9   중랑구
# 10     10   마포구
# 11     11   성동구
# 12     12   구로구
# 13     13  동대문구
# 14     14   강북구
# 15     15   강동구
# 16     16   은평구
# 17     17   종로구
# 18     18   강남구
# 19     19   광진구
# 20     20   동작구
# 21     21  서대문구
# 22     22   관악구

# %%
employee_data4.iloc[:, :1].reset_index()
# Out:
#     index   자치구
# 0       0   강동구
# 1       1   양천구
# 2       2   송파구
# 3       3   강서구
# 4       4   은평구
# 5       5   서초구
# 6       6   노원구
# 7       7   강남구
# 8       8   금천구
# 9       9  영등포구
# 10     10   마포구
# 11     11   중랑구
# 12     12   강북구
# 13     13   성동구
# 14     14   용산구
# 15     15   구로구
# 16     16  동대문구
# 17     17   종로구
# 18     18   광진구
# 19     19   동작구
# 20     20  서대문구
# 21     21   관악구
# 22     22    중구

# %%
final = pd.merge(seoul_pop_data4.iloc[:, :1].reset_index(), float_pop_data4.iloc[:, :1].reset_index(), on = "자치구", how = "left").fillna(11)

# %%
final = final.rename(columns = {"index_x" : "pop_rank", "index_y" : "floatpop_rank"})

# %%
final = pd.merge(final, seoul_income_data5.iloc[:, :1].reset_index(), on = "자치구", how = "inner").rename(columns = {"index" : "income_rank"})

# %%
final = pd.merge(final, employee_data4.iloc[:, :1].reset_index(), on = "자치구", how = "inner").rename(columns = {"index" : "employee_rank"})

# %%
final = final.iloc[:, [1, 0, 2, 3, 4]]

# %%
final["overrated_point"] = final.iloc[:, 1:].sum(axis = 1)
# Out:
# C:\Users\ITSC\AppData\Local\Temp\ipykernel_10976\3745164652.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final["overrated_point"] = final.iloc[:, 1:].sum(axis = 1)

# %%
final = final.sort_values(by = "overrated_point").reset_index(drop = True)

# %%
final.to_csv("./conclusion.csv")

# %%
final
# Out:
#      자치구  pop_rank  floatpop_rank  income_rank  employee_rank  overrated_point
# 0   영등포구         4            0.0            0              9             13.0
# 1    서초구         1           10.0            1              5             17.0
# 2    금천구         7            4.0            2              8             21.0
# 3    강서구         0           15.0            5              3             23.0
# 4    노원구         2           12.0            3              6             23.0
# 5    송파구         6            8.0            8              2             24.0
# 6    용산구         3            5.0            7             14             29.0
# 7    마포구        10            2.0           10             10             32.0
# 8    양천구        21            9.0            6              1             37.0
# 9    성동구        12            6.0           11             13             42.0
# 10   은평구         8           18.0           16              4             46.0
# 11   강북구         5           17.0           14             12             48.0
# 12  동대문구        19            1.0           13             16             49.0
# 13   구로구        16            7.0           12             15             50.0
# 14   강남구        15           11.0           18              7             51.0
# 15   강동구        18           20.0           15              0             53.0
# 16   중랑구        20           14.0            9             11             54.0
# 17   동작구        14            3.0           20             19             56.0
# 18    중구        22           11.0            4             22             59.0
# 19   종로구         9           19.0           17             17             62.0
# 20   광진구        13           13.0           19             18             63.0
# 21  서대문구        11           16.0           21             20             68.0
# 22   관악구        17           21.0           22             21             81.0

# %% [markdown]
# ## 결론 검증 및 보강

# %%
seoul_sales = pd.read_csv("C:/Users/ITSC/Desktop/MiniPrj2/Git/Data/자치구별 매출액.csv", names = ["자치구", "매출(억)"])

# %%
seoul_sales
# Out:
#      자치구  매출(억)
# 0    강서구   4287
# 1    양천구   2613
# 2    구로구   3001
# 3    마포구   4410
# 4   영등포구   5231
# 5    금천구   1752
# 6    관악구   2547
# 7    동작구   1779
# 8    용산구   3225
# 9   서대문구   1771
# 10   은평구   2007
# 11   종로구   3032
# 12    중구   7434
# 13   성북구   1779
# 14  동대문구   1930
# 15   성동구   2307
# 16   서초구   8039
# 17   강남구  12000
# 18   송파구   6554
# 19   광진구   2357
# 20   강동구   2452
# 21   중랑구   1589
# 22   강북구   1252
# 23   도봉구   1260
# 24   노원구   2612

# %%
verify01 = pd.merge(pd.merge(final, seoul_sales, on = "자치구", how = "left"), seoul_district.iloc[:, 1:], on = "자치구", how = "inner")

# %%
verify01["매출/(면적*임대료)"] = verify01["매출(억)"] / (verify01["면적 (km²)"] * verify01["중대형 1층"])

# %%
verify01.iloc[:, [0, 5, 6, -1]]
# Out:
#      자치구  overrated_point  매출(억)  매출/(면적*임대료)
# 0   영등포구             13.0   5231     6.158247
# 1    서초구             17.0   8039     5.155175
# 2    금천구             21.0   1752     4.053079
# 3    강서구             23.0   4287     2.938233
# 4    노원구             23.0   2612     2.489934
# 5    송파구             24.0   6554     4.839816
# 6    용산구             29.0   3225     3.632076
# 7    마포구             32.0   4410     4.080001
# 8    양천구             37.0   2613     4.440419
# 9    성동구             42.0   2307     3.078746
# 10   은평구             46.0   2007     1.465358
# 11   강북구             48.0   1252     1.155037
# 12  동대문구             49.0   1930     3.062372
# 13   구로구             50.0   3001     3.299891
# 14   강남구             51.0  12000     4.707119
# 15   강동구             53.0   2452     2.112613
# 16   중랑구             54.0   1589     2.260313
# 17   동작구             56.0   1779     2.023085
# 18    중구             59.0   7434     8.640722
# 19   종로구             62.0   3032     1.721309
# 20   광진구             63.0   2357     2.629104
# 21  서대문구             68.0   1771     1.589458
# 22   관악구             81.0   2547     1.183168

# %%
url = "https://golmok.seoul.go.kr/stateArea.do"

page = urlopen(url)

soup = BeautifulSoup(page, "html.parser")

# %%
soup.select("tbody tr.branch.collapsed td")
# Out:
# []

# %%
url = "https://golmok.seoul.go.kr/stateArea.do"

driver = webdriver.Chrome()
driver.get(url)

driver.implicitly_wait(2)

addr = driver.find_element(By.CSS_SELECTOR, "#stateArea > div.searchArea.forMo > div.swiper-container.swiper_infotype.swiper-container-horizontal.swiper-container-free-mode > div > div:nth-child(4)")
addr.click( ) 

driver.implicitly_wait(2)

addr2 = driver.find_element(By.CSS_SELECTOR, "#stateArea > div.searchArea.forMo > div.btn > div")
addr2.click( )

time.sleep(5)

soup = BeautifulSoup(driver.page_source, "lxml")

# %%
table = [i.text for i in soup.select("tbody tr.branch.collapsed td")]

# %%
table
# Out:
# ['하위 메뉴 펼침종로구',
#  '업종 전체',
#  '81.9',
#  '60.3',
#  '49.2',
#  '81.4',
#  '61.3',
#  '52.5',
#  '82',
#  '64.1',
#  '54',
#  '하위 메뉴 펼침중구',
#  '업종 전체',
#  '82.3',
#  '60.3',
#  '49.1',
#  '79.2',
#  '58.6',
#  '48.1',
#  '83',
#  '64.6',
#  '54.7',
#  '하위 메뉴 펼침용산구',
#  '업종 전체',
#  '80.2',
#  '58.1',
#  '47.5',
#  '80.5',
#  '60.8',
#  '49.6',
#  '81.6',
#  '63.1',
#  '52.7',
#  '하위 메뉴 펼침성동구',
#  '업종 전체',
#  '81.5',
#  '61',
#  '49.4',
#  '80.1',
#  '59.3',
#  '48.7',
#  '81.5',
#  '62.6',
#  '51.5',
#  '하위 메뉴 펼침광진구',
#  '업종 전체',
#  '77.7',
#  '52.5',
#  '42.1',
#  '77',
#  '57.2',
#  '45.2',
#  '78.2',
#  '58.5',
#  '47.2',
#  '하위 메뉴 펼침동대문구',
#  '업종 전체',
#  '78.7',
#  '54.6',
#  '43.5',
#  '78.1',
#  '55.9',
#  '45.3',
#  '76',
#  '56.6',
#  '46.8',
#  '하위 메뉴 펼침중랑구',
#  '업종 전체',
#  '72.2',
#  '48.1',
#  '37.7',
#  '74.9',
#  '53.9',
#  '43.3',
#  '76',
#  '55.3',
#  '44.7',
#  '하위 메뉴 펼침성북구',
#  '업종 전체',
#  '77',
#  '52.3',
#  '40.9',
#  '77.6',
#  '56.6',
#  '45.8',
#  '78.7',
#  '59.4',
#  '48.6',
#  '하위 메뉴 펼침강북구',
#  '업종 전체',
#  '72.5',
#  '47.7',
#  '36.7',
#  '73.6',
#  '50.2',
#  '40.9',
#  '74.1',
#  '52.3',
#  '41.6',
#  '하위 메뉴 펼침도봉구',
#  '업종 전체',
#  '74.6',
#  '48.8',
#  '38.7',
#  '75.8',
#  '54.1',
#  '43.6',
#  '76.5',
#  '56.4',
#  '45.7',
#  '하위 메뉴 펼침노원구',
#  '업종 전체',
#  '76.3',
#  '52.7',
#  '40.9',
#  '74.4',
#  '53.5',
#  '42.3',
#  '76.1',
#  '57.9',
#  '47.4',
#  '하위 메뉴 펼침은평구',
#  '업종 전체',
#  '76.3',
#  '52.4',
#  '41.7',
#  '74.3',
#  '50.9',
#  '40.4',
#  '77.4',
#  '58.6',
#  '46.7',
#  '하위 메뉴 펼침서대문구',
#  '업종 전체',
#  '76.9',
#  '54.4',
#  '43.1',
#  '76.8',
#  '54.8',
#  '44.3',
#  '78.8',
#  '57.5',
#  '46.4',
#  '하위 메뉴 펼침마포구',
#  '업종 전체',
#  '77.5',
#  '52.5',
#  '41.2',
#  '76.5',
#  '53.3',
#  '42.2',
#  '79.4',
#  '58.5',
#  '47',
#  '하위 메뉴 펼침양천구',
#  '업종 전체',
#  '76.2',
#  '51.3',
#  '39.8',
#  '75.1',
#  '53.7',
#  '43',
#  '77.8',
#  '57.1',
#  '45',
#  '하위 메뉴 펼침강서구',
#  '업종 전체',
#  '76.9',
#  '55',
#  '44',
#  '77.7',
#  '54.7',
#  '43.3',
#  '79.3',
#  '59.6',
#  '48.7',
#  '하위 메뉴 펼침구로구',
#  '업종 전체',
#  '76.3',
#  '52',
#  '42.2',
#  '77.3',
#  '55.2',
#  '44.7',
#  '76.9',
#  '59.3',
#  '48.6',
#  '하위 메뉴 펼침금천구',
#  '업종 전체',
#  '78.6',
#  '54.3',
#  '44.9',
#  '77.1',
#  '57.3',
#  '47.4',
#  '80.5',
#  '62',
#  '51.1',
#  '하위 메뉴 펼침영등포구',
#  '업종 전체',
#  '77.2',
#  '54.4',
#  '43.4',
#  '78',
#  '55.7',
#  '45.8',
#  '80',
#  '60.9',
#  '50',
#  '하위 메뉴 펼침동작구',
#  '업종 전체',
#  '77.4',
#  '55.3',
#  '44.4',
#  '78.1',
#  '52.9',
#  '42',
#  '77.5',
#  '58.2',
#  '46.5',
#  '하위 메뉴 펼침관악구',
#  '업종 전체',
#  '71.5',
#  '47.4',
#  '35.7',
#  '72.3',
#  '49.6',
#  '38',
#  '76.3',
#  '55.8',
#  '43.5',
#  '하위 메뉴 펼침서초구',
#  '업종 전체',
#  '79.5',
#  '57.3',
#  '46.4',
#  '79.9',
#  '60',
#  '49.6',
#  '81.9',
#  '63.3',
#  '53.2',
#  '하위 메뉴 펼침강남구',
#  '업종 전체',
#  '76.7',
#  '54.2',
#  '44.5',
#  '77.6',
#  '57',
#  '47.9',
#  '80.2',
#  '61.5',
#  '51.8',
#  '하위 메뉴 펼침송파구',
#  '업종 전체',
#  '78.2',
#  '54.8',
#  '44.6',
#  '76.9',
#  '56.4',
#  '45.9',
#  '79',
#  '59.8',
#  '48.9',
#  '하위 메뉴 펼침강동구',
#  '업종 전체',
#  '74.7',
#  '51.4',
#  '41.3',
#  '74.7',
#  '52',
#  '41.7',
#  '76.2',
#  '55.8',
#  '45.4']

# %%
table2 = pd.DataFrame([table[i*11:i*11+11] for i in range(int(len(table)/11))])

# %%
table2 = table2.iloc[:, [0, 8, 9, 10]]

# %%
table2 = table2.rename(columns = {0 : "자치구", 8 : "1년생존", 9 : "3년생존", 10 : "5년생존"})

# %%
table2["자치구"] = table2["자치구"].str.slice(start = 8)

# %%
table2 = table2.sort_values("자치구").reset_index(drop = True)

# %%
table2["1년생존률평가"] = table2["1년생존"].astype(float)-79
table2["3년생존률평가"] = table2["3년생존"].astype(float)-59.6
table2["5년생존률평가"] = table2["5년생존"].astype(float)-48.9

# %%
table2
# Out:
#      자치구  1년생존  3년생존  5년생존  1년생존률평가  3년생존률평가  5년생존률평가
# 0    강남구  80.2  61.5  51.8      1.2      1.9      2.9
# 1    강동구  76.2  55.8  45.4     -2.8     -3.8     -3.5
# 2    강북구  74.1  52.3  41.6     -4.9     -7.3     -7.3
# 3    강서구  79.3  59.6  48.7      0.3      0.0     -0.2
# 4    관악구  76.3  55.8  43.5     -2.7     -3.8     -5.4
# 5    광진구  78.2  58.5  47.2     -0.8     -1.1     -1.7
# 6    구로구  76.9  59.3  48.6     -2.1     -0.3     -0.3
# 7    금천구  80.5    62  51.1      1.5      2.4      2.2
# 8    노원구  76.1  57.9  47.4     -2.9     -1.7     -1.5
# 9    도봉구  76.5  56.4  45.7     -2.5     -3.2     -3.2
# 10  동대문구    76  56.6  46.8     -3.0     -3.0     -2.1
# 11   동작구  77.5  58.2  46.5     -1.5     -1.4     -2.4
# 12   마포구  79.4  58.5    47      0.4     -1.1     -1.9
# 13  서대문구  78.8  57.5  46.4     -0.2     -2.1     -2.5
# 14   서초구  81.9  63.3  53.2      2.9      3.7      4.3
# 15   성동구  81.5  62.6  51.5      2.5      3.0      2.6
# 16   성북구  78.7  59.4  48.6     -0.3     -0.2     -0.3
# 17   송파구    79  59.8  48.9      0.0      0.2      0.0
# 18   양천구  77.8  57.1    45     -1.2     -2.5     -3.9
# 19  영등포구    80  60.9    50      1.0      1.3      1.1
# 20   용산구  81.6  63.1  52.7      2.6      3.5      3.8
# 21   은평구  77.4  58.6  46.7     -1.6     -1.0     -2.2
# 22   종로구    82  64.1    54      3.0      4.5      5.1
# 23    중구    83  64.6  54.7      4.0      5.0      5.8
# 24   중랑구    76  55.3  44.7     -3.0     -4.3     -4.2

# %%
verify02 = pd.merge(pd.merge(final, table2, on = "자치구", how = "left"), seoul_district.iloc[:, 1:], on = "자치구", how = "inner")

# %%
verify02.iloc[:, [0, 5, 9, 10, 11]]
# Out:
#      자치구  overrated_point  1년생존률평가  3년생존률평가  5년생존률평가
# 0   영등포구             13.0      1.0      1.3      1.1
# 1    서초구             17.0      2.9      3.7      4.3
# 2    금천구             21.0      1.5      2.4      2.2
# 3    강서구             23.0      0.3      0.0     -0.2
# 4    노원구             23.0     -2.9     -1.7     -1.5
# 5    송파구             24.0      0.0      0.2      0.0
# 6    용산구             29.0      2.6      3.5      3.8
# 7    마포구             32.0      0.4     -1.1     -1.9
# 8    양천구             37.0     -1.2     -2.5     -3.9
# 9    성동구             42.0      2.5      3.0      2.6
# 10   은평구             46.0     -1.6     -1.0     -2.2
# 11   강북구             48.0     -4.9     -7.3     -7.3
# 12  동대문구             49.0     -3.0     -3.0     -2.1
# 13   구로구             50.0     -2.1     -0.3     -0.3
# 14   강남구             51.0      1.2      1.9      2.9
# 15   강동구             53.0     -2.8     -3.8     -3.5
# 16   중랑구             54.0     -3.0     -4.3     -4.2
# 17   동작구             56.0     -1.5     -1.4     -2.4
# 18    중구             59.0      4.0      5.0      5.8
# 19   종로구             62.0      3.0      4.5      5.1
# 20   광진구             63.0     -0.8     -1.1     -1.7
# 21  서대문구             68.0     -0.2     -2.1     -2.5
# 22   관악구             81.0     -2.7     -3.8     -5.4
